# %%
import numpy as np
import qutip as qt
import matplotlib.pyplot as plt

# Parámetros
g = 1.0       # Tasa de detección
phi = 0.0         # Fase del oscilador local
t_max = 40
dt = 0.01# Tiempo total de simulación
tlist = np.linspace(0,40,1000)
Omega = 3      # Frecuencia de Rabi
steps = int(t_max / dt)
Delta =0
# Definimos los estados base y excitado para un sistema de dos niveles
Kg = qt.basis(2, 0)  # estado base |g⟩
Ke = qt.basis(2, 1)  # estado excitado |e⟩

## Espacio de hilbert

Aee = Ke*Ke.dag()
Agg = Kg*Kg.dag()
Aeg = Ke*Kg.dag()
Age = Kg*Ke.dag()



expect_values = [
Agg,Aee] #Los valores esperados se ponen en forma de lista, no se si importe su orden


psi0=Kg
# Operadores cuánticos
sm = qt.destroy(2)   # Operador de aniquilación (sigma_-)
sp = sm.dag()        # Operador de creación (sigma_+)
sigma_phi = (sp * np.exp(1j * phi) + sm * np.exp(-1j * phi)) / 2  # Operador de cuadratura


sigma_z = Ke * Ke.dag() - Kg * Kg.dag()
# Hamiltoniano
H = 0.5 * Delta * qt.sigmaz()+0.5 * Omega * (sm + sp)  # Hamiltoniano con frecuencia de Rabi
Ceg = np.sqrt(g) * Kg * Ke.dag()
collapse = [Ceg]

# Estado inicial en superposición
psi_t = (qt.basis(2, 0) + qt.basis(2, 1)).unit()

result = qt.mesolve(H, psi0, tlist, collapse,expect_values)

# %%
plt.figure(figsize=(8,6))

# Resultados de la ecuación maestra
plt.plot(tlist,result.expect[1], label=r'$\rho_{ee}(t)$ - Eq. Maestra', linestyle='-', linewidth=0.6, color='blue')
plt.plot(tlist,result.expect[0], label=r'$\rho_{gg}(t)$ - Eq. Maestra', linestyle='-', linewidth=0.6, color='red')


# Etiquetas de los ejes
plt.xlabel(r'$\gamma t$', fontsize=20)
plt.ylabel(r'$\rho_{ee}(t)$', fontsize=20)

# Límites de los ejes
plt.ylim(0, 1)

# Leyenda
plt.legend(loc=1, prop={'size': 15})

# Texto adicional en la gráfica
plt.figtext(0.5, -0.05, 
            r'Comparación entre la ecuación maestra y las trayectorias cuánticas para $\rho_{ee}(t)$ '
            r'$\Omega = %.2f$, $\Delta = %.2f$, $\gamma_a = %.2f$, $\gamma_d = %.2f$, $\gamma = %.2f$, $\Delta t = %i$', 
            ha='center', fontsize=12)

# Guardar la figura
#plt.savefig('Comparacion_EqMaestra_Trayectorias.pdf')

# Mostrar la figura
plt.show()

# %%
# Rango de frecuencias para el espectro
wlist = np.linspace(-10, 10, 500)

# Calcular la función de correlación <sigma_phi(t) sigma_phi(0)>
corr = qt.correlation_3op_1t(H, psi0, tlist, collapse, sigma_p, sigma_p.dag())

# Obtener el espectro como la transformada de Fourier de la correlación
S_w = np.abs(np.fft.fftshift(np.fft.fft(corr)))  

# Graficar el espectro
plt.figure(figsize=(8, 5))
plt.plot(wlist, S_w, label="Espectro de emisión")
plt.xlabel("Frecuencia (ω)")
plt.ylabel("Intensidad")
plt.title("Triplete de Mollow")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       2 wlist = np.linspace(-10, 10, 500)
#       4 # Calcular la función de correlación <sigma_phi(t) sigma_phi(0)>
# ----> 5 corr = qt.correlation_3op_1t(H, psi0, tlist, collapse, sigma_p, sigma_p.dag())
#       7 # Obtener el espectro como la transformada de Fourier de la correlación
#       8 S_w = np.abs(np.fft.fftshift(np.fft.fft(corr)))
#
# NameError: name 'sigma_p' is not defined

# %%
Agg
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[1. 0.]
#  [0. 0.]]

# %%
sigma_m
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dia, isherm=False
# Qobj data =
# [[0. 1.]
#  [0. 0.]]

# %%
sigma_p
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dia, isherm=False
# Qobj data =
# [[0. 0.]
#  [1. 0.]]

# %%
Aee
# Out:
# Quantum object: dims=[[2], [2]], shape=(2, 2), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0. 0.]
#  [0. 1.]]
