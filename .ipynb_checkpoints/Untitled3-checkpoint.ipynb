# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt

NF = 3
Kg = basis(NF, 2)
Ka = basis(NF, 1)
Ke = basis(NF, 0)

# Estado inicial
psi0 = Kg 

# Definición de operadores de colapso y Hamiltoniano
Aaa = Ka * Ka.dag()
Aee = Ke * Ke.dag()
Agg = Kg * Kg.dag()
Aeg = Ke * Kg.dag()
Aag = Ka * Kg.dag()
Aea = Ke * Ka.dag()
Aae = Ka * Ke.dag()
Aga = Kg * Ka.dag()
Age = Kg * Ke.dag()

Omega = 3.5  # Frecuencia de Rabi
Delta = 0    # Desintonía
ga = 0.015 
gd = 0.05
g = 0.95
deltat = 10000
ntraj = 100

# Operador de colapso para la emisión detectable
Ceg = np.sqrt(g) * Age
collapse = [Ceg]

# Hamiltoniano
H = Delta * Aee + 0.5 * Omega * (Aeg + Age)

# Lista de tiempos para la simulación
tlist = np.linspace(0, 900, deltat)

# Listas para almacenar tiempos de espera
wait_times = []

# Simulación Monte Carlo para medir tiempos de espera
for _ in range(ntraj):
    result = mcsolve(H, psi0, tlist, collapse, [Aee, Agg, Aaa], 1)
    
    # Registrar el primer colapso de excitado a base
    if result.col_times and len(result.col_times[0]) > 0:
        wait_times.append(result.col_times[0][0])  # Primer tiempo de colapso
    else:
        # Si no hubo colapso en el tiempo simulado, usa el tiempo máximo
        wait_times.append(tlist[-1])

# Análisis posterior: añadir tiempos oscuros
num_dark_times = int(0.05 * len(wait_times))  # 5% de tiempos oscuros
mean_dark_time = np.mean(wait_times) * 15  # Tiempo oscuro promedio, ajustable

# Generar tiempos oscuros adicionales
dark_times = np.random.exponential(scale=mean_dark_time, size=num_dark_times)

# Combinar tiempos originales y tiempos oscuros
combined_times = np.concatenate((wait_times, dark_times))

# Mostrar resultados
print("Tiempos de espera hasta el primer colapso (Aeg):", wait_times)
print("Tiempos oscuros añadidos:", dark_times)

# Graficar los tiempos
plt.hist(combined_times, bins=50, alpha=0.7, label="Tiempos combinados")
plt.xlabel("Tiempo")
plt.ylabel("Frecuencia")
plt.legend()
plt.title("Distribución de Tiempos de Espera con Tiempos Oscuros Añadidos")
plt.show()
# Out:
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.58s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.58s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.68s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.70s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.73s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.71s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.58s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.56s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.58s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.59s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.70s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.63s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.66s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.67s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.63s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.66s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.58s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.66s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.69s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.68s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.72s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.66s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.67s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.63s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.66s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.84s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.68s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.57s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.58s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.68s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.63s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.69s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.69s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.68s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.67s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.68s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.68s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.67s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.61s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.69s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.65s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.66s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.67s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.70s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.63s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.69s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.62s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.64s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.71s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.67s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.60s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.68s
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# Total run time:   1.72s
# Tiempos de espera hasta el primer colapso (Aeg): [0.7557645083994825, 1.6306659426979444, 0.5080490660726469, 0.46207275106660856, 1.2906786374678751, 4.3723390978666155, 0.4497962814890512, 0.8229822279266501, 0.5906404370320254, 4.753847870773148, 4.509210685555177, 1.1027962152906168, 2.3168404322906118, 2.193887966106932, 0.4331557887265765, 6.367212029818006, 0.7305624365889681, 0.4885456935696188, 5.7677162924226275, 2.117551520702204, 6.765699755281625, 3.8791857615298735, 0.584181732381567, 0.7872841959519307, 0.27653345533209633, 2.7505189195942203, 6.39009490153349, 0.8979002005756995, 0.8269523888650127, 0.23985691565503997, 3.2309678386404195, 0.8937532658262564, 1.1661733260750884, 1.3447133427577525, 4.899378966269426, 0.5403665428644457, 4.588254440792252, 3.389720655150064, 0.5325444872213809, 0.5832181917611026, 0.2544058433141569, 1.0258059748710715, 0.6765482969744758, 8.22518866907591, 2.8181237978421474, 2.1825145060157847, 1.1516002288437486, 4.103074781717951, 0.3382000111184201, 1.0582548082459249, 0.9384487066922089, 0.3720779140666666, 8.09584559977443, 3.9487653508783036,