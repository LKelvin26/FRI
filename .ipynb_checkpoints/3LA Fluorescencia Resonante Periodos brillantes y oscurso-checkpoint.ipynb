# %% [markdown]
# # Programa de la solución de las trayectorias cuánticas para el sistema de 3 niveles.
# ## Distribución de periodos brillantes y obscuros
# ## Distrubución de tiempos de espera
# ## Distribución de conteo de fotones

# %% [markdown]
# ## Figura del proyecto

# %% [markdown]
# <img src="3LAkev.png" alt="a" class="bg-primary mb-1" width="400px">

# %%
import qutip 
from qutip import *
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pylab import *

# %% [markdown]
# ### La funcion basis es para el número de estados de Fock en el espacio de Hilbert. Si es una lista, entonces el objeto resultante será un producto tensorial  sobre espacios con esas dimensiones.

# %%
NF=3
Kg = basis(NF,2)
Ka = basis(NF,1)
Ke = basis(NF,0)

# Estado base
psi0 = Kg

# %% [markdown]
# ### Para describir los estados de sistemas cuánticos multipartitos (como dos qubits acoplados, un qubit acoplado a un oscilador, etc.) necesitamos expandir el espacio de Hilbert tomando el producto tensorial de los vectores de estado para cada uno de los componentes del sistema. De manera similar, los operadores que actúan sobre los vectores de estado en el espacio de Hilbert combinado (que describe el sistema acoplado) se forman tomando el producto tensorial de los operadores individuales.

# %%
Aaa = Ka*Ka.dag()
Aee = Ke*Ke.dag()
Agg = Kg*Kg.dag()
Aeg = Ke*Kg.dag()
Aag = Ka*Kg.dag()
Aea = Ke*Ka.dag()
Aae = Ka*Ke.dag()
Aga = Kg*Ka.dag()
Age = Kg*Ke.dag()

#Valores esperados
ket_a = Aaa #Definiendo los valores esperados con la diagonal principal
ket_e = Aee
ket_g = Agg

expect_values = [Aaa,
Aee,
Agg] #Los valores esperados se ponen en forma de lista, no se si importe su orden

# %% [markdown]
# ### Parametros del experimento.

# %%
Omega = 1 #Frecuencia de rabi
Delta = 0 #Desintonia
ga = 0.015 
gd = 0.05
g = 0.95
ntraj = 1 # Numero de trayectorias 
tlist = np.linspace(0,1000000,10000)

#El numero de trayectorias necesarias para ver periodos brillantes y obscuros tiene que ser 1 
#De lo contrario como ensamble no se ve porque en el mismo coinciden periodos brillantes con los obscuros de otros 
#Esta parpadeo es caracteristico de puntos cuanticos, átomos y algunas moleculas

# %% [markdown]
# ### Operadores de colapso

# %%
# Operadores de colapso
Ceg = np.sqrt(g)*Age 
Cea = np.sqrt(gd)*Aae
Cag = np.sqrt(ga)*Aga
collapse = [Ceg ,Cea, Cag] #Ceg colapso 0, Cea colapso 1, Cag colapso 2

# %% [markdown]
# ### Hamiltoniano

# %%
#Hamiltoniano del sistema, no se le añaden los terminos de los colapsos porque el programa de la solucion de montecarlo
#lo hace en automatico  con la funcion de liuvillian(H)
H = Delta * Aee + 0.5 * Omega * (Aeg + Age)

# %% [markdown]
# ### Metodo de montecarlo para resolver las trayectorias cuanticas-

# %%
MC = mcsolve(H, psi0, tlist, collapse , expect_values, 1)
#La funcion MC para resolver las trayectorias, H es el hamiltoniano, psi0 son las condiciones iniciales.
#tlist es el tiempo con delta t dependiendo de la funcion linspace, collapse los operadores de colapso, expect_values los 
#valores esperados y ntraj el numero de trayectorias.
# Out:
# 100.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 MC = mcsolve(H, psi0, tlist, collapse , expect_values, 1)
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\mcsolve.py:165, in mcsolve(H, state, tlist, c_ops, e_ops, ntraj, args, options, seeds, target_tol, timeout, **kwargs)
#     159     raise TypeError(
#     160         "ntraj must be an integer. "
#     161         "A list of numbers is not longer supported."
#     162     )
#     163 mc = MCSolver(H, c_ops, options=options)
# --> 165 result = mc.run(state, tlist=tlist, ntraj=ntraj, e_ops=e_ops,
#     166                 seeds=seeds, target_tol=target_tol, timeout=timeout)
#     167 return result
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\mcsolve.py:492, in MCSolver.run(self, state, tlist, ntraj, args, e_ops, timeout, target_tol, seeds)
#     486 def run(self, state, tlist, ntraj=1, *,
#     487         args=None, e_ops=(), timeout=None, target_tol=None, seeds=None):
#     488     # Overridden to sample the no-jump trajectory first. Then, the no-jump
#     489     # probability is used as a lower-bound for random numbers in future
#     490     # monte carlo runs
#     491     if not self.options.get("improved_sampling", False):
# --> 492         return super().run(state, tlist, ntraj=ntraj, args=args,
#     493                            e_ops=e_ops, timeout=timeout,
#     494                            target_tol=target_tol, seeds=seeds)
#     495     stats, seeds, result, map_func, map_kw, state0 = self._initialize_run(
#     496         state,
#     497         ntraj,
#    (...)
#     502         seeds=seeds,
#     503     )
#     504     # first run the no-jump trajectory
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\multitraj.py:224, in MultiTrajSolver.run(self, state, tlist, ntraj, args, e_ops, timeout, target_tol, seeds)
#     214 stats, seeds, result, map_func, map_kw, state0 = self._initialize_run(
#     215     state,
#     216     ntraj,
#    (...)
#     221     seeds=seeds,
#     222 )
#     223 start_time = time()
# --> 224 map_func(
#     225     self._run_one_traj, seeds,
#     226     (state0, tlist, e_ops),
#     227     reduce_func=result.add, map_kw=map_kw,
#     228     progress_bar=self.options["progress_bar"],
#     229     progress_bar_kwargs=self.options["progress_kwargs"]
#     230 )
#     231 result.stats['run time'] = time() - start_time
#     232 return result
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\parallel.py:117, in serial_map(task, values, task_args, task_kwargs, reduce_func, map_kw, progress_bar, progress_bar_kwargs)
#     115 except Exception as err:
#     116     if map_kw["fail_fast"]:
# --> 117         raise err
#     118     else:
#     119         errors[n] = err
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\parallel.py:114, in serial_map(task, values, task_args, task_kwargs, reduce_func, map_kw, progress_bar, progress_bar_kwargs)
#     112 progress_bar.update()
#     113 try:
# --> 114     result = task(value, *task_args, **task_kwargs)
#     115 except Exception as err:
#     116     if map_kw["fail_fast"]:
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\mcsolve.py:481, in MCSolver._run_one_traj(self, seed, state, tlist, e_ops, **integrator_kwargs)
#     477 def _run_one_traj(self, seed, state, tlist, e_ops, **integrator_kwargs):
#     478     """
#     479     Run one trajectory and return the result.
#     480     """
# --> 481     seed, result = super()._run_one_traj(seed, state, tlist, e_ops,
#     482                                          **integrator_kwargs)
#     483     result.collapse = self._integrator.collapses
#     484     return seed, result
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\multitraj.py:249, in MultiTrajSolver._run_one_traj(self, seed, state, tlist, e_ops, **integrator_kwargs)
#     244 """
#     245 Run one trajectory and return the result.
#     246 """
#     247 result = self._initialize_run_one_traj(seed, state, tlist, e_ops,
#     248                                        **integrator_kwargs)
# --> 249 return self._integrate_one_traj(seed, tlist, result)
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\multitraj.py:252, in MultiTrajSolver._integrate_one_traj(self, seed, tlist, result)
#     251 def _integrate_one_traj(self, seed, tlist, result):
# --> 252     for t, state in self._integrator.run(tlist):
#     253         result.add(t, self._restore_state(state, copy=False))
#     254     return seed, result
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\mcsolve.py:276, in MCIntegrator.run(self, tlist)
#     274 def run(self, tlist):
#     275     for t in tlist[1:]:
# --> 276         yield self.integrate(t, False)
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\mcsolve.py:263, in MCIntegrator.integrate(self, t, copy)
#     261 norm = self._prob_func(state)
#     262 if norm <= self.target_norm:
# --> 263     t_col, state = self._find_collapse_time(norm_old, norm,
#     264                                             t_old, t_step)
#     265     self._do_collapse(t_col, state)
#     266     t_old, y_old = self._integrator.get_state(copy=False)
#
# File ~\anaconda3\Lib\site-packages\qutip\solver\mcsolve.py:325, in MCIntegrator._find_collapse_time(self, norm_old, norm, t_prev, t_final)
#     322         norm_old = norm2_guess
#     324 if tries >= self.options['norm_steps']:
# --> 325     raise RuntimeError(
#     326         "Could not find the collapse time within desired tolerance. "
#     327         "Increase accuracy of the ODE solver or lower the tolerance "
#     328         "with the options 'norm_steps', 'norm_tol', 'norm_t_tol'.")
#     330 return t_guess, state
#
# RuntimeError: Could not find the collapse time within desired tolerance. Increase accuracy of the ODE solver or lower the tolerance with the options 'norm_steps', 'norm_tol', 'norm_t_tol'.

# %%
collapse = MC.col_which;
times = MC.col_times;
collapse_list = list(zip(collapse[0], times[0]))
lc=collapse_list
data = pd.DataFrame(collapse_list, columns=['colapso','tiempo'])
a=data[data['colapso']==2]
b=data[data['colapso']==1]
c=data[data['colapso']==0]

tamax=len(lc)

# %% [markdown]
# ## Distribución de periodos brillantes y obscuros

# %%
# Tiempo en el que ocurren los periodos oscuros
tod=0
toscuro=0
cnt=0
tdur=[]
tbdur=[]
tiempos=[]
tiemposb=[]
a=0
for i in lc:
    if lc[cnt][0] == 1 and cnt<tamax-2:
        tb=lc[cnt][1]-lc[a][1]
        tbdur.append(tb)
        tbrillante=tb
        tiemposb.append(lc[a][1])
        
        tod=lc[cnt+2][1]-lc[cnt][1]
        toscuro=toscuro+tod
        tdur.append(tod) 
        tdo=lc[cnt][1]+lc[cnt+2][1]
        tiempos.append(tdo*0.5)
        a=cnt
    cnt=cnt+1
tiempos.pop(0) 
tdur.pop(0) 
tiempos.pop(len(tiempos)-1) 
tdur.pop(len(tdur)-1) 

tiemposb.pop(0) 
tbdur.pop(0) 
tiemposb.pop(len(tiempos)-1) 
tbdur.pop(len(tdur)-1)
# Out:
# 84.23938210937195

# %%
collapse = MC.col_which
times = MC.col_times
collapse_list = list(zip(collapse[0], times[0]))
lc = collapse_list
data = pd.DataFrame(collapse_list, columns=['colapso', 'tiempo'])

tamax = len(lc)

# Inicialización de variables
tod = 0
toscuro = 0
cnt = 0
tdur = []
tbdur = []
tiempos = []
tiemposb = []

a = 0  # Inicialización del índice

# Bucle para calcular los tiempos brillantes y oscuros
for i in lc:
    if lc[cnt][0] == 1 and cnt < tamax - 2:
        tb = lc[cnt][1] - lc[a][1]
        tbdur.append(tb)
        tiemposb.append(lc[a][1])

        if cnt + 2 < tamax:  # Validación para evitar índices fuera de rango
            tod = lc[cnt + 2][1] - lc[cnt][1]
            toscuro = toscuro + tod
            tdur.append(tod)
            tdo = lc[cnt][1] + lc[cnt + 2][1]
            tiempos.append(tdo * 0.5)
        a = cnt  # Actualizamos el índice de referencia
    cnt += 1

# Eliminar el primer y último elemento solo si las listas no están vacías
if len(tiempos) > 1:
    tiempos.pop(0)
    tiempos.pop(len(tiempos) - 1)

if len(tdur) > 1:
    tdur.pop(0)
    tdur.pop(len(tdur) - 1)

if len(tiemposb) > 1:
    tiemposb.pop(0)
    tiemposb.pop(len(tiemposb) - 1)

if len(tbdur) > 1:
    tbdur.pop(0)
    tbdur.pop(len(tbdur) - 1)

# %%
plt.figure(figsize=(8,6))
plt.bar(tiemposb,tbdur, label =r'tiempo en el que ocurre un periodo brillante',width=30)
plt.xlabel(r'$\gamma t$',fontsize=20)
plt.ylabel(r'Duración ($\gamma^-1$)',fontsize=20)
tbrill=10000-toscuro

# %%
plt.figure(figsize=(8,6))
plt.bar(tiempos,tdur, label =r'tiempo en el que ocurre un periodo oscuro',width=30)
plt.xlabel(r'$\gamma t$',fontsize=20)
plt.ylabel(r'Duración ($\gamma^-1$)',fontsize=20)
tbrill=10000-toscuro
plt.ylim(0,400)
# Out:
# (0.0, 400.0)

# %%
# Histograma de la duracion de periodos oscuros
plt.figure(figsize=(8,6))
plt.hist(tdur,20,histtype ='barstacked',label='Hisotograma de la duracion de periodos oscuros',rwidth=1,edgecolor='black',color='red')
plt.xlabel(r'$\gamma t$',fontsize=20)
plt.ylabel('Número de periodos oscuros',fontsize=20)
# Out:
# Text(0, 0.5, 'Número de periodos oscuros')

# %%
# Histograma de la duracion de periodos brillantes
plt.figure(figsize=(8,6))
plt.hist(tbdur,20,histtype ='barstacked',label='Hisotograma de la duracion de periodos oscuros',rwidth=1,edgecolor='black',color='red')
plt.xlabel(r'$\gamma t$',fontsize=20)
plt.ylabel('Número de periodos oscuros',fontsize=20)
# Out:
# Text(0, 0.5, 'Número de periodos oscuros')

# %%
'''
Comparacion de los periodos brillantes y oscuros medidos con los de las formulas
Omega = 1 #Frecuencia de rabi
Delta = 0 #Desintonia
ga = 0.015 
gd = 0.05
g = 0.935
tlist
'''

#Promedio periodos oscuros
tlis = np.linspace(0,800,950)
a=np.mean(tdur)
Toc=1/ga
TBc=(2*Omega**3+g**2+4*Delta**2)/(gd*Omega**2)
POc=(300000)*(1/Toc)*exp(-tlis/Toc)
PBc=(1/Toc)*exp(-tlis/TBc)
plt.figure(figsize=(8,6))
plt.plot(tlis,POc,color="black")
plt.hist(tdur,bins=28,histtype ='barstacked',label='Hisotograma de la duracion de periodos oscuros',rwidth=1,edgecolor='black',color='magenta')
plt.xlabel(r'$\gamma t$',fontsize=20)
plt.ylabel(r'Número de periodos oscuros ',fontsize=20)
plt.xlim(0,600)
plt.ylim(0,6000)
a
# Out:
# 67.77283030962462

# %%
'''
Comparacion de los periodos brillantes y oscuros medidos con los de las formulas
Omega = 1 #Frecuencia de rabi
Delta = 0 #Desintonia
ga = 0.015 
gd = 0.05
g = 0.935
tlist
'''

#Promedio periodos oscuros
tlis = np.linspace(0,800,950)
a=np.mean(tdur)
Toc=1/ga
TBc=(2*Omega**3+g**2+4*Delta**2)/(gd*Omega**2)
POc=(300000)*(1/Toc)*exp(-tlis/Toc)
PBc=(200000)*(1/Toc)*exp(-tlis/TBc)
plt.figure(figsize=(8,6))
plt.plot(tlis,PBc,color="black")
plt.hist(tbdur,bins=21,histtype ='barstacked',label='Hisotograma de la duracion de periodos oscuros',rwidth=1,edgecolor='black',color='magenta')
plt.xlabel(r'$\gamma t$',fontsize=20)
plt.ylabel(r'Número de periodos brillantes ',fontsize=20)
plt.xlim(0,600)
plt.ylim(0,3100)
a
# Out:
# 67.77283030962462

# %% [markdown]
# ## Poblaciones

# %%
plt.figure(figsize=(8,6))
#plt.bar(tiempos,tdur,width=50,color='orange')

#plt.plot(tlist,MC.expect[0], label =r'$\rho_{aa}(t)$', linestyle='-',linewidth = 0.6, color = 'green')
plt.plot(tlist,MC.expect[1], label =r'$\rho_{ee}(t)$', linestyle='-',linewidth = 0.6, color = 'black')
#plt.plot(tlist,MC.expect[2], label =r'$\rho_{gg}(t)$', linestyle='dashdot',linewidth = 0.5, color = 'orange')
plt.xlabel(r'$\gamma t$',fontsize=20)
plt.ylabel(r'$\rho_{ee}(t)$',fontsize=20)
#plt.xlim(0,100000)
#plt.legend(loc=1, prop={'size': 25})
#plt.savefig('Fig. 2a.pdf')
#plt.show()
plt.figtext(0.5, -0.05, 
            r'Evolución temporal de la poblacion del estado exitado de 1 trayectoria '
            r'$\Omega = %.2f$, $\Delta = %.2f$, $\gamma_a = %.2f$, $\gamma_d = %.2f$, $\gamma = %.2f$,$\Delta t = %i$' % (Omega, Delta, ga, gd, g,deltat), 
            ha='center', fontsize=12)
# Out:
# Text(0.5, -0.05, 'Evolución temporal de la poblacion del estado exitado de 1 trayectoria $\\Omega = 3.50$, $\\Delta = 0.00$, $\\gamma_a = 0.01$, $\\gamma_d = 0.05$, $\\gamma = 0.95$,$\\Delta t = 10000$')

# %% [markdown]
# ##
